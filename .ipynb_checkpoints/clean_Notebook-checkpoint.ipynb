# %% [markdown]
# # **Setup**

# %%
#@title #Setup: Imports and dependencies
#@markdown Install and import Python dependencies.
location = 'vsc' #@param['colab', 'vsc']

package = 'inseq' #@param['inseq', 'kayo', 'both']

# !pip install jsonlines
import jsonlines
import json
import re
from transformers import GPT2Tokenizer, GPT2LMHeadModel
import copy
import sys
import torch
from IPython.display import clear_output
import numpy as np
import gc
import argparse
from collections import defaultdict
import pandas as pd
import matplotlib as plt

import random
random.seed(42)

tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
model = GPT2LMHeadModel.from_pretrained("gpt2")

if package == 'inseq' or package == 'both':
  print('Installing dependencies inseq')
  # !pip install inseq
  import inseq


if package == 'kayo' or package == 'both':
  print('Installing dependencies kayo')
  # !pip3 install torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu113
  # !git clone https://github.com/JanAthmer/Baseline_clusters.git &> /dev/null
#   !git clone https://github.com/kayoyin/interpret-lm.git &> /dev/null
  sys.path.append('./Baseline_clusters')
#   sys.path.append('./interpret-lm')

  from lm_saliency import *

clear_output()

print('Done!')
# Out:
# Done!

# %%
#@title #Setup: load Drive
if location == 'colab':
  from google.colab import drive
  drive.mount('/content/drive')

# %%
#@title #Setup: Utils

def average(lst):
  return sum(lst)/len(lst)

def avg_arr(array, x):
    avg = np.mean(array[:x])  # Calculate the average of the first x values
    array[:x] = avg  # Replace the first x values with the calculated average
    return array

def reciprocal_rank(predictions, targets):
    # Combine predictions and targets into pairs
    pairs = list(zip(predictions, targets))

    # Sort the pairs based on the prediction values (in descending order)
    sorted_pairs = sorted(pairs, key=lambda x: x[0], reverse=True)

    # Find the rank of the first correct prediction
    rank = next((i + 1 for i, (pred, target) in enumerate(sorted_pairs) if target), 0)

    # Calculate reciprocal rank
    reciprocal_rank = 1 / rank if rank > 0 else 0

    return reciprocal_rank

def get_target_any(sentence):
    b = sentence.split(' ')
    prefix_l = 0
    postix_l = 0
    target_l = 0
    check = False
    for i,word in enumerate(b):
        if i != 0:
            word = " "+word

        if check == True:
            postix_l += len(tokenizer(word)['input_ids'])
        if " not" == word:
            target_l = len(tokenizer(word)['input_ids'])
            check = True
        if check == False:
            prefix_l += len(tokenizer(word)['input_ids'])
    return([False]*prefix_l+[True]*target_l+[False]*postix_l)


import random

def generate_one_hot_list(length):
    # Check if the length is valid
    if length <= 0:
        raise ValueError("Length must be greater than 0")

    # Choose a random index for the "hot" element
    hot_index = random.randint(0, length - 1)

    # Create the one-hot list
    one_hot_list = [0] * length
    one_hot_list[hot_index] = 1

    return one_hot_list

def get_last_true_index(one_hot_vector):
    """
    Get the index of the last True value in the one-hot vector.

    Parameters:
    one_hot_vector (list of bool): One-hot vector with possibly multiple True values.

    Returns:
    int: The index of the last True value in the one-hot vector, or -1 if no True values are found.
    """
    last_true_index = -1
    for i, value in enumerate(one_hot_vector):
        if value:
            last_true_index = i
    return last_true_index

def normalize_vector(vector):
    """
    Normalize a vector between -1 and 1 by dividing each element by the absolute maximum value.

    Args:
    vector (numpy array): The input vector to be normalized.

    Returns:
    numpy array: The normalized vector.
    """
    abs_max = max(abs(np.max(vector)), abs(np.min(vector)))
    normalized_vector = vector / abs_max
    return normalized_vector


def normalize_and_truncate(vector_a, vector_b):
    """
    Normalize two input vectors between -1 and 1 and truncate the longer vector to match the length of the shorter one.

    Args:
    vector_a (numpy array): The first input vector to be normalized and truncated.
    vector_b (numpy array): The second input vector to be normalized and truncated.

    Returns:
    numpy array, numpy array: The normalized and truncated vectors A and B.
    """
    # Normalize vector A
    abs_max_a = max(abs(np.max(vector_a)), abs(np.min(vector_a)))
    normalized_vector_a = vector_a / abs_max_a

    # Normalize vector B
    abs_max_b = max(abs(np.max(vector_b)), abs(np.min(vector_b)))
    normalized_vector_b = vector_b / abs_max_b

    # Determine which vector is longer and truncate it
    if len(normalized_vector_a) > len(normalized_vector_b):
        truncated_vector_a = normalized_vector_a[:len(normalized_vector_b)]
        truncated_vector_b = normalized_vector_b
    else:
        truncated_vector_a = normalized_vector_a
        truncated_vector_b = normalized_vector_b[:len(normalized_vector_a)]

    return truncated_vector_a, truncated_vector_b

# %%
#@title #Setup: Load Data

pattern = r"\b(\w+)n't\b"
def expand_contractions(sentence):
    return re.sub(pattern, lambda match: match.group(1) + " not", sentence)

with jsonlines.open("anaphor_gender_agreement.jsonl", 'r') as f:
  dataframe_aga = pd.DataFrame(f)

with jsonlines.open("determiner_noun_agreement_1.jsonl", 'r') as f:
  dataframe_dna = pd.DataFrame(f)

sentences = []
values = []
with open("prefix+value.tsv", 'r', encoding='utf-8') as ifh:
  for line in ifh:
      sentence, value = line.strip().split('\t')
      sentences.append(sentence)
      values.append(value)
  expanded_sentences = [expand_contractions(sentence) for sentence in sentences]
  dataframe_any = pd.DataFrame({'one_prefix_prefix': expanded_sentences})





# Apply the function to each sentence

with open("vocab_tagged.json", 'r') as file:
    vocabulary = json.load(file)

# %%
dataframe_any = dataframe_any.drop_duplicates()
print(len(dataframe_any['one_prefix_prefix'].tolist()))
b = False
amount_to_remove = 1400

for sentence in dataframe_any['one_prefix_prefix'].tolist():
    booleans = get_target(sentence)
    i = 1
    b = False
    for boole in booleans:
        if boole:
          b = True
        if not boole and b:
          i +=1
    if i == 2 and amount_to_remove!=0:
        amount_to_remove = amount_to_remove -1
        dataframe_any = dataframe_any.drop(dataframe_any[dataframe_any['one_prefix_prefix'] == sentence].index)
dataframe_any.reset_index(drop=True, inplace=True)
print(len(dataframe_any['one_prefix_prefix'].tolist()))
# Out:
# 2608
# 1208

# %% [markdown]
# # **Main function and loop**

# %%
dataframe_aga
# Out:
#                         sentence_good                      sentence_bad  \
# 0       Katherine can't help herself.     Katherine can't help himself.
# 1      Karla could listen to herself.    Karla could listen to himself.
# 2    Marie won't think about herself.   Marie won't think about itself.
# 3      Mark hasn't discussed himself.     Mark hasn't discussed itself.
# 4          Stephen impressed himself.         Stephen impressed itself.
# ..                                ...                               ...
# 995  Carlos complained about himself.   Carlos complained about itself.
# 996       Benjamin is firing himself.        Benjamin is firing itself.
# 997              Chad kisses himself.              Chad kisses herself.
# 998  Paula was arguing about herself.  Paula was arguing about himself.
# 999  Colleen should question herself.   Colleen should question itself.
#
#            one_prefix_prefix one_prefix_word_good one_prefix_word_bad  \
# 0       Katherine can't help              herself             himself
# 1      Karla could listen to              herself             himself
# 2    Marie won't think about              herself              itself
# 3      Mark hasn't discussed              himself              itself
# 4          Stephen impressed              himself              itself
# ..                       ...                  ...                 ...
# 995  Carlos complained about              himself              itself
# 996       Benjamin is firing              himself              itself
# 997              Chad kisses              himself             herself
# 998  Paula was arguing about              herself             himself
# 999  Colleen should question              herself              itself
#
#           field   linguistics_term                       UID  \
# 0    morphology  anaphor_agreement  anaphor_gender_agreement
# 1    morphology  anaphor_agreement  anaphor_gender_agreement
# 2    morphology  anaphor_agreement  anaphor_gender_agreement
# 3    morphology  anaphor_agreement  anaphor_gender_agreement
# 4    morphology  anaphor_agreement  anaphor_gender_agreement
# ..          ...                ...                       ...
# 995  morphology  anaphor_agreement  anaphor_gender_agreement
# 996  morphology  anaphor_agreement  anaphor_gender_agreement
# 997  morphology  anaphor_agreement  anaphor_gender_agreement
# 998  morphology  anaphor_agreement  anaphor_gender_agreement
# 999  morphology  anaphor_agreement  anaphor_gender_agreement
#
#      simple_LM_method  one_prefix_method  two_prefix_method  \
# 0                True               True              False
# 1                True               True              False
# 2                True               True              False
# 3                True               True              False
# 4                True               True              False
# ..                ...                ...                ...
# 995              True               True              False
# 996              True               True              False
# 997              True               True              False
# 998              True               True              False
# 999              True               True              False
#
#      lexically_identical pairID
# 0                  False      0
# 1                  False      1
# 2                  False      2
# 3                  False      3
# 4                  False      4
# ..                   ...    ...
# 995                False    995
# 996                False    996
# 997                False    997
# 998                False    998
# 999                False    999
#
# [1000 rows x 13 columns]

# %%
#@title #Main Function
def rr_attribution(model_inseq, attributed_fn, sentence, target, targets, contrastive = True, foil = None, baseline = True, rnd = None, headlen = None, data = None, norm = None):
    
    if attributed_fn == 'logit':
        contrast_attributed_fn = "contrast_logits_diff"
    elif attributed_fn == 'probability':
        contrast_attributed_fn = "contrast_prob_diff"
    
    warnings.filterwarnings("ignore", message="No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute Filling missing position with right-aligned 1:1 position alignments")

    if baseline:
        base = model_inseq.attribute(
                  sentence,
                  sentence + " " + target,
                  attributed_fn= attributed_fn,
                  show_progress = False
                )

        base_att = base[0].target_attributions
        if explanation != 'occlusion' and norm == 'sum':
            base_att = base_att.sum(axis = 2)
        elif norm == 'L2':
            base_att = torch.linalg.norm(base_att,axis = 2)
        base_att = torch.flatten(base_att[~torch.any(base_att.isnan(),dim=1)]).numpy()

 
    if contrastive:
        con = model_inseq.attribute(
          sentence,
          sentence + " " + target,
          attributed_fn= contrast_attributed_fn,
          contrast_targets= sentence + " " + foil,
          step_scores=[contrast_attributed_fn],
          show_progress = False
        )
        
        con_att = con[0].target_attributions
        if explanation != 'occlusion' and norm == 'sum':
            con_att = con_att.sum(axis = 2)
        elif norm == 'L2':
            con_att = torch.linalg.norm(con_att,axis = 2)
        con_att = torch.flatten(con_att[~torch.any(con_att.isnan(),dim=1)]).numpy()
   
    if rnd != None:
        con_rnd = model_inseq.attribute(
          sentence,
          sentence + " " + target,
          attributed_fn= contrast_attributed_fn,
          contrast_targets= sentence + " " + rnd,
          step_scores=[contrast_attributed_fn],
          show_progress = False
        )
        
        con_rnd_att = con_rnd[0].target_attributions
        if explanation != 'occlusion' and norm == 'sum':
            con_rnd_att = con_rnd_att.sum(axis = 2)
        elif norm == 'L2':
            con_rnd_att = torch.linalg.norm(con_rnd_att,axis = 2)
        con_rnd_att = torch.flatten(con_rnd_att[~torch.any(con_rnd_att.isnan(),dim=1)]).numpy()
        
        
    if norm == 'sum':
        base_att_rev = base_att*-1
        con_att_rev = con_att*-1
        con_rnd_att_rev = con_rnd_att*-1
    else:
        base_att_rev = base_att
        con_att_rev = con_att
        con_rnd_att_rev = con_rnd_att
        
        
    if data == 'aga':
        if headlen > 1:
            base_att = avg_arr(base_att, headlen)
            base_att_rev = avg_arr(base_att_rev, headlen)
            con_att = avg_arr(con_att, headlen)
            con_att_rev= avg_arr(con_att_rev, headlen)
            con_rnd_att= avg_arr(con_rnd_att, headlen)
            con_rnd_att_rev= avg_arr(con_rnd_att_rev, headlen)
            
    base_rank = reciprocal_rank(base_att, targets)
    base_rank_rev = reciprocal_rank(base_att_rev, targets)
    con_rank = reciprocal_rank(con_att, targets)
    con_rank_rev = reciprocal_rank(con_att_rev, targets)
    con_rnd_rank = reciprocal_rank(con_rnd_att, targets)
    con_rnd_rank_rev = reciprocal_rank(con_rnd_att_rev, targets)
    
    
    
    if baseline and contrastive and (rnd!=None):
        return base_att,base_att_rev,con_att,con_att_rev,con_rnd_att,con_rnd_att_rev,base_rank,base_rank_rev,con_rank,con_rank_rev,con_rnd_rank,con_rnd_rank_rev
    elif baseline and contrastive:
        return base_rank,base_rank_rev,con_rank,con_rank_rev
    elif baseline:
        return base_rank,base_rank_rev
    elif contrastive:
        return con_rank,con_rank_rev
    elif (rnd!=None):
        return con_rnd_rank,con_rnd_rank_rev

# %%
#@title #Main Loop
import warnings
from numpy import linalg
explanations    = ["input_x_gradient"]#,  "lime", "occlusion"
datasets        = ["aga"]#, "dna","any"
attributed_fns  = ["logit"]#,"probability"
norms           = ['L2', 'sum']

df = pd.DataFrame(columns=['Rank','Value', 'Sentence'])
for norm in norms:
    for explanation in explanations:
        model_inseq = inseq.load_model("gpt2", explanation)

        for data in datasets:
            i = 0
            for attributed_fn in attributed_fns:
                if data == 'any':
                    dataframe = dataframe_any
                elif data == 'aga':    
                    dataframe = dataframe_npi
                elif data == 'dna':
                    dataframe = dataframe_dna

                for index, row in dataframe.iterrows():

                    i+=1
                    print(f'{explanation}_{data}_{attributed_fn}_{i}')

                    if data == 'any':
                      sentence = row["one_prefix_prefix"]
                      target = "any"
                      foil = "some"
                      targets = get_target(sentence)

                    elif data == 'aga':                    
                      sentence = row["one_prefix_prefix"]
                      target = row["one_prefix_word_good"]
                      foil = row["one_prefix_word_bad"]

                      total_len = len(tokenizer.tokenize(sentence))
                      headlen = len(tokenizer.tokenize(sentence.split(' ')[0]))
                      targets =  [True]+(total_len-headlen)*[False]

                    elif data == 'dna':
                      sentence = row["one_prefix_prefix"]
                      target = row["one_prefix_word_good"]
                      foil = row["one_prefix_word_bad"]

                      total_len = len(tokenizer.tokenize(sentence))
                      headlen = len(tokenizer.tokenize(sentence.split(' ')[-1]))
                      targets =  (total_len-headlen)*[False]+[True]


                    foil_rnd = random.sample(vocabulary,1)[0][0][0]

                    base_rr, base_rev_rr,con_rr, con_rev_rr, con_rnd_rr, con_rnd_rev_rr,base_rank,base_rank_rev,con_rank,con_rank_rev,con_rnd_rank,con_rnd_rank_rev = rr_attribution(
                        model_inseq,attributed_fn,sentence, target,targets, rnd = foil_rnd, foil = foil, headlen = headlen, data = data, norm = norm)                

                    # Create DataFrames for each row
                    new_rows = [
                        {'Rank':base_rank ,'Sentence':sentence ,'Value': base_rr, 'explanations': f'{explanation}', 'datasets': f'{data}', 'attributed_fns': f'{attributed_fn}', 'methods': 'baseline', 'reversed': 'original', 'norm': f'{norm}'},
                        {'Rank':base_rank_rev ,'Sentence':sentence ,'Value': base_rev_rr, 'explanations': f'{explanation}', 'datasets': f'{data}', 'attributed_fns': f'{attributed_fn}', 'methods': 'baseline', 'reversed': 'reversed', 'norm': f'{norm}'},
                        {'Rank':con_rank ,'Sentence':sentence ,'Value': con_rr, 'explanations': f'{explanation}', 'datasets': f'{data}', 'attributed_fns': f'{attributed_fn}', 'methods': 'contrastive', 'reversed': 'original', 'norm': f'{norm}'},
                        {'Rank':con_rank_rev ,'Sentence':sentence ,'Value': con_rev_rr, 'explanations': f'{explanation}', 'datasets': f'{data}', 'attributed_fns': f'{attributed_fn}', 'methods': 'contrastive', 'reversed': 'reversed', 'norm': f'{norm}'},
                        {'Rank':con_rnd_rank ,'Sentence':sentence ,'Value': con_rnd_rr, 'explanations': f'{explanation}', 'datasets': f'{data}', 'attributed_fns': f'{attributed_fn}', 'methods': 'cont_rnd', 'reversed': 'original', 'norm': f'{norm}'},
                        {'Rank':con_rnd_rank_rev ,'Sentence':sentence ,'Value': con_rnd_rev_rr, 'explanations': f'{explanation}', 'datasets': f'{data}', 'attributed_fns': f'{attributed_fn}', 'methods': 'cont_rnd', 'reversed': 'reversed', 'norm': f'{norm}'}                    
                    ]

                    # Concatenate the new rows with the DataFrame
                    df = pd.concat([df, pd.DataFrame(new_rows)], ignore_index=True)

# Create a MultiIndex from the dimensions
df.set_index(['explanations', 'datasets', 'attributed_fns', 'methods', 'reversed', 'norm'], inplace=True)

df
# Create the DataFrame using the MultiIndex and data
# df.to_csv('full_results_sum.csv')
# Out:
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# input_x_gradient_aga_logit_1
# input_x_gradient_aga_logit_2
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# input_x_gradient_aga_logit_3
# input_x_gradient_aga_logit_4
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# input_x_gradient_aga_logit_5
# input_x_gradient_aga_logit_6
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# input_x_gradient_aga_logit_7
# input_x_gradient_aga_logit_8
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# input_x_gradient_aga_logit_9
# input_x_gradient_aga_logit_10
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# input_x_gradient_aga_logit_11
# input_x_gradient_aga_logit_12
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# input_x_gradient_aga_logit_13
# input_x_gradient_aga_logit_14
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# input_x_gradient_aga_logit_15
# input_x_gradient_aga_logit_16
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# input_x_gradient_aga_logit_17
# input_x_gradient_aga_logit_18
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# input_x_gradient_aga_logit_19
# input_x_gradient_aga_logit_20
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# input_x_gradient_aga_logit_21
# input_x_gradient_aga_logit_22
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# input_x_gradient_aga_logit_23
# input_x_gradient_aga_logit_24
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# input_x_gradient_aga_logit_25
# input_x_gradient_aga_logit_26
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# input_x_gradient_aga_logit_27
# input_x_gradient_aga_logit_28
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# input_x_gradient_aga_logit_29
# input_x_gradient_aga_logit_30
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# input_x_gradient_aga_logit_31
# input_x_gradient_aga_logit_32
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# input_x_gradient_aga_logit_33
# input_x_gradient_aga_logit_34
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# input_x_gradient_aga_logit_35
# input_x_gradient_aga_logit_36
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# input_x_gradient_aga_logit_37
# input_x_gradient_aga_logit_38
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# input_x_gradient_aga_logit_39
# input_x_gradient_aga_logit_40
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# input_x_gradient_aga_logit_41
# input_x_gradient_aga_logit_42
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# input_x_gradient_aga_logit_43
# input_x_gradient_aga_logit_44
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# input_x_gradient_aga_logit_45
# input_x_gradient_aga_logit_46
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# input_x_gradient_aga_logit_47
# input_x_gradient_aga_logit_48
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# input_x_gradient_aga_logit_49
# input_x_gradient_aga_logit_50
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# input_x_gradient_aga_logit_51
# input_x_gradient_aga_logit_52
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# input_x_gradient_aga_logit_53
# input_x_gradient_aga_logit_54
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# input_x_gradient_aga_logit_55
# input_x_gradient_aga_logit_56
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# input_x_gradient_aga_logit_57
# input_x_gradient_aga_logit_58
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# input_x_gradient_aga_logit_59
# input_x_gradient_aga_logit_60
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# input_x_gradient_aga_logit_61
# input_x_gradient_aga_logit_62
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# input_x_gradient_aga_logit_63
# input_x_gradient_aga_logit_64
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# input_x_gradient_aga_logit_65
# input_x_gradient_aga_logit_66
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# input_x_gradient_aga_logit_67
# input_x_gradient_aga_logit_68
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# input_x_gradient_aga_logit_69
# input_x_gradient_aga_logit_70
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# input_x_gradient_aga_logit_71
# input_x_gradient_aga_logit_72
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# input_x_gradient_aga_logit_73
# input_x_gradient_aga_logit_74
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# input_x_gradient_aga_logit_75
# input_x_gradient_aga_logit_76
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# input_x_gradient_aga_logit_77
# input_x_gradient_aga_logit_78
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# input_x_gradient_aga_logit_79
# input_x_gradient_aga_logit_80
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# input_x_gradient_aga_logit_81
# input_x_gradient_aga_logit_82
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# input_x_gradient_aga_logit_83
# input_x_gradient_aga_logit_84
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# input_x_gradient_aga_logit_85
# input_x_gradient_aga_logit_86
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# input_x_gradient_aga_logit_87
# input_x_gradient_aga_logit_88
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# input_x_gradient_aga_logit_89
# input_x_gradient_aga_logit_90
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# input_x_gradient_aga_logit_91
# input_x_gradient_aga_logit_92
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# input_x_gradient_aga_logit_93
# input_x_gradient_aga_logit_94
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# input_x_gradient_aga_logit_95
# input_x_gradient_aga_logit_96
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# input_x_gradient_aga_logit_97
# input_x_gradient_aga_logit_98
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# input_x_gradient_aga_logit_99
# input_x_gradient_aga_logit_100
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# input_x_gradient_aga_logit_101
# input_x_gradient_aga_logit_102
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# ...
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# input_x_gradient_aga_logit_975
# input_x_gradient_aga_logit_976
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# input_x_gradient_aga_logit_977
# input_x_gradient_aga_logit_978
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# input_x_gradient_aga_logit_979
# input_x_gradient_aga_logit_980
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# input_x_gradient_aga_logit_981
# input_x_gradient_aga_logit_982
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# input_x_gradient_aga_logit_983
# input_x_gradient_aga_logit_984
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# input_x_gradient_aga_logit_985
# input_x_gradient_aga_logit_986
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# input_x_gradient_aga_logit_987
# input_x_gradient_aga_logit_988
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# input_x_gradient_aga_logit_989
# input_x_gradient_aga_logit_990
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# input_x_gradient_aga_logit_991
# input_x_gradient_aga_logit_992
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# input_x_gradient_aga_logit_993
# input_x_gradient_aga_logit_994
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# input_x_gradient_aga_logit_995
# input_x_gradient_aga_logit_996
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# input_x_gradient_aga_logit_997
# input_x_gradient_aga_logit_998
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# No target alignments were provided for the contrastive target. Use e.g. 'contrast_targets_alignments=[(0,1), ...] to provide them in model.attribute
# Filling missing position with right-aligned 1:1 position alignments.
# input_x_gradient_aga_logit_999
# input_x_gradient_aga_logit_1000
#                                                                         Rank  \
# explanations     datasets attributed_fns methods     reversed norm
# input_x_gradient aga      logit          baseline    original L2    0.333333
#                                                      reversed L2    0.333333
#                                          contrastive original L2    0.500000
#                                                      reversed L2    0.500000
#                                          cont_rnd    original L2    0.333333
# ...                                                                      ...
#                                          baseline    reversed sum   0.333333
#                                          contrastive original sum   0.250000
#                                                      reversed sum   0.500000
#                                          cont_rnd    original sum   0.333333
#                                                      reversed sum   0.333333
#
#                                                                                                                 Value  \
# explanations     datasets attributed_fns methods     reversed norm
# input_x_gradient aga      logit          baseline    original L2                    [1.6028825, 2.3737047, 4.2576385]
#                                                      reversed L2                    [1.6028825, 2.3737047, 4.2576385]
#                                          contrastive original L2                 [0.20205119, 0.34231144, 0.10868286]
#                                                      reversed L2                 [0.20205119, 0.34231144, 0.10868286]
#                                          cont_rnd    original L2                  [0.24217255, 0.33264118, 0.6901123]
# ...                                                                                                               ...
#                                          baseline    reversed sum   [-1.8370826, -1.6042613, -2.7574966, -1.445038...
#                                          contrastive original sum   [-0.111523464, 1.2573192, -0.05796624, -0.2832...
#                                                      reversed sum   [0.111523464, -1.2573192, 0.05796624, 0.283232...
#                                          cont_rnd    original sum   [-0.23656696, 0.8143483, -0.2609766, -0.219420...
#                                                      reversed sum   [0.23656696, -0.8143483, 0.2609766, 0.21942095...
#
#                                                                                  Sentence
# explanations     datasets attributed_fns methods     reversed norm
# input_x_gradient aga      logit          baseline    original L2         Even Suzanne has
#                                                      reversed L2         Even Suzanne has
#                                          contrastive original L2         Even Suzanne has
#                                                      reversed L2         Even Suzanne has
#                                          cont_rnd    original L2         Even Suzanne has
# ...                                                                                   ...
#                                          baseline    reversed sum   Even the cashiers had
#                                          contrastive original sum   Even the cashiers had
#                                                      reversed sum   Even the cashiers had
#                                          cont_rnd    original sum   Even the cashiers had
#                                                      reversed sum   Even the cashiers had
#
# [12000 rows x 3 columns]

# %%
df.loc[('input_x_gradient', 'aga', 'logit', 'baseline', 'original', 'L2'), 'Rank'].mean()
# Out:
# 0.41684999999999994

# %%
#@title #Main Function
def att_attribution(model_inseq, sentence, target,targets, contrastive = False, foil = None, headlen = None, data = None, norm = None ):      
    
    base = model_inseq.attribute(
              sentence,
              sentence + " " + target,
              attributed_fn= attributed_fn,
              show_progress = False
            )

    base_att = base[0].target_attributions
    if explanation != 'occlusion' and norm == 'sum':
        base_att = base_att.sum(axis = 2)
    elif norm == 'L2':
        base_att = torch.linalg.norm(base_att,axis = 2)
    if explanation == 'attention':
        #sum over heads
        base_att = base_att.sum(axis = -1)
    base_att = torch.flatten(base_att[~torch.any(base_att.isnan(),dim=1)]).numpy()
    
    
    if data == 'aga':
        if headlen > 1:
            base_att = avg_arr(base_att, headlen)
            
    base_rank = reciprocal_rank(base_att, targets)
    
    return base_att, base_rank

# %%
#@title #Main Loop
import warnings
warnings.filterwarnings("ignore")
explanations    = ["attention", "deeplift", "integrated_gradients", "gradient_shap", "discretized_integrated_gradients"]
datasets        = ["aga", "dna","any"]
attributed_fns  = ["logit"]
norms = ['sum', 'L2']
df = pd.DataFrame(columns=['Value', 'Rank', 'Sentence'])
for norm in norms:
    for explanation in explanations:
        model_inseq = inseq.load_model("gpt2", explanation)

        for data in datasets:
            i = 0
            for attributed_fn in attributed_fns:
                if data == 'any':
                    dataframe = dataframe_any
                elif data == 'aga':    
                    dataframe = dataframe_aga
                elif data == 'dna':
                    dataframe = dataframe_dna

                for index, row in dataframe.iterrows():

                    i+=1
                    print(f'{explanation}_{data}_{attributed_fn}_{i}')

                    if data == 'any':
                      sentence = row["one_prefix_prefix"]
                      target = "any"
                      foil = "some"
                      targets = get_target(sentence)
                        
                    elif data == 'aga':                    
                      sentence = row["one_prefix_prefix"]
                      target = row["one_prefix_word_good"]
                      foil = row["one_prefix_word_bad"]

                      total_len = len(tokenizer.tokenize(sentence))
                      headlen = len(tokenizer.tokenize(sentence.split(' ')[0]))
                      targets =  [True]+(total_len-headlen)*[False]

                    elif data == 'dna':
                      sentence = row["one_prefix_prefix"]
                      target = row["one_prefix_word_good"]
                      foil = row["one_prefix_word_bad"]

                      total_len = len(tokenizer.tokenize(sentence))
                      headlen = len(tokenizer.tokenize(sentence.split(' ')[-1]))
                      targets =  (total_len-headlen)*[False]+[True]

                    base_att,base_rank = att_attribution(model_inseq,sentence, target, targets, headlen = headlen, data = data, norm = norm)
                    # Create DataFrames for each row
                    new_rows = [
                        {'Rank': base_rank, 'Sentence':sentence ,'Value': base_att, 'explanations': f'{explanation}', 'datasets': f'{data}', 'attributed_fns': f'{attributed_fn}', 'methods': 'baseline', 'reversed': 'original', 'norm': f'{norm}'},
                    ]

                    # Concatenate the new rows with the DataFrame
                    df = pd.concat([df, pd.DataFrame(new_rows)], ignore_index=True)
                    clear_output()

# Create a MultiIndex from the dimensions
df.set_index(['explanations', 'datasets', 'attributed_fns', 'methods', 'reversed', 'norm'], inplace=True)

# Create the DataFrame using the MultiIndex and data
df.to_csv('aga_rerun_rest.csv')
# Out:
# Internals attribution methods are output agnostic, since they do not rely on specific output targets to compute importance scores. Using a custom attributed function in this context does not influence in any way the method's results.
# attention_aga_logit_364
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /scratch-local/scur0635.6158054/ipykernel_3366521/2230273608.py in <module>
#      50                       targets =  (total_len-headlen)*[False]+[True]
#      51
# ---> 52                     base_att,base_rank = att_attribution(model_inseq,sentence, target, targets, headlen = headlen, data = data, norm = norm)
#      53                     # Create DataFrames for each row
#      54                     new_rows = [
#
# /scratch-local/scur0635.6158054/ipykernel_3366521/2292403430.py in att_attribution(model_inseq, sentence, target, targets, contrastive, foil, headlen, data, norm)
#       2 def att_attribution(model_inseq, sentence, target,targets, contrastive = False, foil = None, headlen = None, data = None, norm = None ):
#       3
# ----> 4     base = model_inseq.attribute(
#       5               sentence,
#       6               sentence + " " + target,
#
# ~/.local/lib/python3.9/site-packages/inseq/models/attribution_model.py in attribute(self, input_texts, generated_texts, method, override_default_attribution, attr_pos_start, attr_pos_end, show_progress, pretty_progress, output_step_attributions, attribute_target, step_scores, include_eos_baseline, attributed_fn, device, batch_size, generate_from_target_prefix, generation_args, **kwargs)
#     443             logger.info("Batched attribution currently not supported for LIME. Using batch size of 1.")
#     444             batch_size = 1
# --> 445         attribution_outputs = attribution_method.prepare_and_attribute(
#     446             input_texts,
#     447             generated_texts,
#
# ~/.local/lib/python3.9/site-packages/inseq/attr/attribution_decorators.py in batched_wrapper(self, batch_size, *args, **kwargs)
#      69
#      70         if batch_size is None:
# ---> 71             out = f(self, *args, **kwargs)
#      72             return out if isinstance(out, list) else [out]
#      73         batched_args = [get_batched(batch_size, arg) for arg in args]
#
# ~/.local/lib/python3.9/site-packages/inseq/attr/feat/feature_attribution.py in prepare_and_attribute(self, sources, targets, attr_pos_start, attr_pos_end, show_progress, pretty_progress, output_step_attributions, attribute_target, step_scores, include_eos_baseline, attributed_fn, attribution_args, attributed_fn_args, step_scores_args)
#     235         # of AttributionModel.attribute.
#     236         attributed_fn = self.attribution_model.get_attributed_fn(attributed_fn)
# --> 237         attribution_output = self.attribute(
#     238             batch,
#     239             attributed_fn=attributed_fn,
#
# ~/.local/lib/python3.9/site-packages/inseq/attr/feat/feature_attribution.py in attribute(self, batch, attributed_fn, attr_pos_start, attr_pos_end, show_progress, pretty_progress, output_step_attributions, attribute_target, step_scores, attribution_args, attributed_fn_args, step_scores_args)
#     471         end = datetime.now()
#     472         close_progress_bar(pbar, show=show_progress, pretty=pretty_progress)
# --> 473         batch.detach().to("cpu")
#     474         out = FeatureAttributionOutput(
#     475             sequence_attributions=FeatureAttributionSequenceOutput.from_step_attributions(
#
# ~/.local/lib/python3.9/site-packages/inseq/data/data_utils.py in detach(self)
#     150         for field in fields(self.__class__):
#     151             attr = getattr(self, field.name)
# --> 152             setattr(self, field.name, self._detach(attr))
#     153         return self
#     154
#
# ~/.local/lib/python3.9/site-packages/inseq/data/data_utils.py in _detach(attr)
#      79     @staticmethod
#      80     def _detach(attr):
# ---> 81         if isinstance(attr, (torch.Tensor, TensorWrapper)):
#      82             return attr.detach()
#      83         elif isinstance(attr, dict):
#
# KeyboardInterrupt:

# %%
df['Rank'].mean()
# Out:
# 1.0
